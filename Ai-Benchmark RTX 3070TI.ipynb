# %%
from ai_benchmark import AIBenchmark
results = AIBenchmark().run()
# Out:
# >>   AI-Benchmark-v.0.1.2
# >>   Let the AI Games begin..
#
# *  TF Version: 2.10.1
# *  Platform: Windows-10-10.0.22621-SP0
# *  CPU: N/A
# *  CPU RAM: 15 GB
# *  GPU/0: NVIDIA GeForce RTX 3070 Ti Laptop GPU
# *  GPU RAM: 5.3 GB
# *  CUDA Version: 12.1
# *  CUDA Build: V12.1.66
#
# The benchmark is running...
# The tests might take up to 20 minutes
# Please don't interrupt the script
#
# 1/19. MobileNet-V2
#
# 1.1 - inference | batch=50, size=224x224: 63.4 ± 11.9 ms
# 1.2 - training  | batch=50, size=224x224: 99.4 ± 1.8 ms
#
# 2/19. Inception-V3
#
# 2.1 - inference | batch=20, size=346x346: 77.9 ± 15.4 ms
# 2.2 - training  | batch=20, size=346x346: 164 ± 4 ms
#
# 3/19. Inception-V4
#
# 3.1 - inference | batch=10, size=346x346: 54.1 ± 3.2 ms
# 3.2 - training  | batch=10, size=346x346: 168 ± 5 ms
#
# 4/19. Inception-ResNet-V2
#
# 4.1 - inference | batch=10, size=346x346: 68.9 ± 4.7 ms
# 4.2 - training  | batch=8, size=346x346: 163 ± 6 ms
#
# 5/19. ResNet-V2-50
#
# ...
